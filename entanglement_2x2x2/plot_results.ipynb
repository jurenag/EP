# %%
import numpy as np
from modules.plot_results import plot, ASR_grouped_bar_chart
import os
cwd = os.getcwd()

# %% [markdown]
# # 1. Binary experiments

# %% [markdown]
# ## 1.1. RMSprop optimizer

# %%
cwd = os.getcwd()
plot_filepaths = []
plot_filepaths.append(cwd+'/results/definitive_results/rmsprop_trials/GHZ.txt')
plot_filepaths.append(cwd+'/results/definitive_results/rmsprop_trials/GHZ.txt')
plot_filepaths.append(cwd+'/results/definitive_results/rmsprop_trials/W.txt')
plot_filepaths.append(cwd+'/results/definitive_results/rmsprop_trials/W.txt')
plot_filepaths.append(cwd+'/results/definitive_results/rmsprop_trials/BE.txt')
plot_filepaths.append(cwd+'/results/definitive_results/rmsprop_trials/BE.txt')

# %%
x_y_columns = np.array([[0,1],[0,3],[0,1],[0,3],[0,1],[0,3]])

# %%
save_data = []
save_data.append(cwd+'/results/definitive_results/plot_3qubits_RMSprop.eps')
save_data.append('eps')

# %%
plot(plot_filepaths, rows_to_skip=(10,10,10,10,10,10), xycolumns=x_y_columns, stdColumn=(2,4,2,4,2,4), err_every=(1,1,1,1,1,1), plotStd=[True, True, True, True, True, True], labels=['GHZ','GHZ-VL','W','W-VL','BE','BE-VL'], showGrid=True, save_data=save_data, xlim=(0,85), xlabel='Nº Epochs', ylabel='BCE loss', legendfontsize=12, legendncol=3, labelsfontsize=20, ticksfontsize=14)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
cwd = os.getcwd()
plot_filepaths = []
plot_filepaths.append(cwd+'/results/rmsprop/[256,128,64,1]/100k/GHZ_500epochs.txt')
plot_filepaths.append(cwd+'/results/rmsprop/[256,128,64,1]/100k/GHZ_500epochs.txt')

# %%
x_y_columns = np.array([[0,1],[0,3]])

# %%
save_data = []
save_data.append(cwd+'/results/definitive_results/overfitting[256,128,64].eps')
save_data.append('eps')

# %%
plot(plot_filepaths, rows_to_skip=(8,8), xycolumns=x_y_columns, stdColumn=(2,4), err_every=(1,1), plotStd=[True, True], labels=['GHZ','GHZ-VL'], showGrid=True, save_data=save_data, xlim=(0,500), xlabel='Nº Epochs', ylabel='BCE loss', legendfontsize=12, legendncol=3, labelsfontsize=20, ticksfontsize=14)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
cwd = os.getcwd()
plot_filepaths = []
plot_filepaths.append(cwd+'/results/[256,128,64,32,16,8,1]/100k/GHZ_GOOD_ONE.txt')
plot_filepaths.append(cwd+'/results/[256,128,64,32,16,8,1]/100k/GHZ_GOOD_ONE.txt')

# %%
x_y_columns = np.array([[0,1],[0,3]])

# %%
plot(plot_filepaths, rows_to_skip=(8,8), xycolumns=x_y_columns, stdColumn=(2,4), err_every=(1,1), plotStd=[True, True], labels=['GHZ_L','GHZ_VL'], showGrid=True, xlim=(1,100), ylim=(0,1), xlabel='Nº Epochs', ylabel='BCE loss')

# %% [markdown]
# ## 1.2. Adam results with Early Stopping

# %%
cwd = os.getcwd()
plot_filepaths = []
plot_filepaths.append(cwd+'/results/definitive_results/GHZ_fraction_0.75.txt')
plot_filepaths.append(cwd+'/results/definitive_results/GHZ_fraction_0.75.txt')
plot_filepaths.append(cwd+'/results/definitive_results/W_fraction_0.75.txt')
plot_filepaths.append(cwd+'/results/definitive_results/W_fraction_0.75.txt')
plot_filepaths.append(cwd+'/results/definitive_results/BE_fraction_0.75.txt')
plot_filepaths.append(cwd+'/results/definitive_results/BE_fraction_0.75.txt')

# %%
x_y_columns = np.array([[0,1],[0,3],[0,1],[0,3],[0,1],[0,3]])

# %%
save_data = []
save_data.append(cwd+'/results/definitive_results/plot_3qubits.eps')
save_data.append('eps')

# %%
plot(plot_filepaths, rows_to_skip=(10,10,10,10,10,10), xycolumns=x_y_columns, stdColumn=(2,4,2,4,2,4), err_every=(1,1,1,1,1,1), plotStd=[True, True, True, True, True, True], labels=['GHZ','GHZ-VL','W','W-VL','BE','BE-VL'], showGrid=True, save_data=save_data, xlim=(0,85), xlabel='Nº Epochs', ylabel='BCE loss', legendfontsize=12, legendncol=3, labelsfontsize=20, ticksfontsize=14)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
cwd = os.getcwd()
hist_filepath = cwd+'/results/definitive_results/ASR.txt'

# %%
save_data = []
save_data.append(cwd+'/results/definitive_results/plot_ASR_3qubits.eps')
save_data.append('eps')

# %%
ASR_grouped_bar_chart(hist_filepath, 1, separator='\t', ylim=(0.75,1.05), showGrid=True, save_data=save_data, legend_columns=3, ylabel='Average Sucess Rate', title=None, legendfontsize=12, xlabelfontsize=14, ylabelfontsize=20)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
